# %% [markdown]
# # Basic Bit Manipulation
# > - If you know the basics of Computer Architecture and have read at least 2 chapters of the CSAAP you are good to go.
# > - These Contains some Basic Problems like the below ones
# ![image.png](attachment:image.png)
# <br>
# <br>
# <br>
#
# ### But there is this triky One
#
# <br>
# <br>
#
# ![image-2.png](attachment:image-2.png)
#
# #### you can find the solution in the solution folder of this Directory : )
